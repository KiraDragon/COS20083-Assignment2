# %%
import numpy as np
import math
import datetime
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,confusion_matrix, classification_report

import pandas as pd
import pandas_datareader as web

# %%
start = datetime.datetime(2019,3,9)
end = datetime.datetime(2020,3,12)

df = web.DataReader('5168.KL','yahoo',start,end)
df.to_csv('stock1.csv')
df = pd.read_csv('stock1.csv')
df.tail()
# Out:
#            Date  High   Low  Open  Close      Volume  Adj Close
# 247  2020-03-06  6.42  6.18  6.20   6.40  15176600.0       6.40
# 248  2020-03-09  6.45  6.27  6.44   6.42   8750600.0       6.42
# 249  2020-03-10  6.50  6.31  6.34   6.40   6671700.0       6.40
# 250  2020-03-11  6.50  6.39  6.43   6.48   9303700.0       6.48
# 251  2020-03-12  6.67  6.50  6.50   6.57  11327900.0       6.57

# %%
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

plt.figure(figsize=(12,8))
plt.plot(df['Close'])
plt.xlabel('date')
plt.ylabel('price')
plt.show()

# %%
X = df[['High','Low','Open','Volume']].values
y = df['Close'].values

# %%
train_pct_index = int(0.9*len(x))
X_train, X_test = X[:train_pct_index], X[train_pct_index:]
y_train, y_test = y[:train_pct_index], y[train_pct_index:]

# %%
regressor = LinearRegression()

# %%
regressor.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
regressor.coef_
# Out:
# array([ 7.80561297e-01,  6.17309787e-01, -4.02816186e-01, -2.01115510e-09])

# %%
regressor.intercept_
# Out:
# 0.029083993216608484

# %%
pred = regressor.predict(X_test)

# %%
regressor.score(X_train,y_train)
# Out:
# 0.9902650689855976

# %%
mean_squared_error(y_test,pred)
# Out:
# 0.0021728374891890763

# %%
plt.scatter(pred, y_test, label='Sal')
plt.plot([0, 1], [0, 1], '--k', transform=plt.gca().transAxes)#draws the dotted line
plt.xlabel('pred')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
df = web.DataReader('5347.KL',data_source='yahoo',start='2017-05-2',end='2020-05-01')

# %%
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

plt.figure(figsize=(12,8))
plt.plot(df['Close'])
plt.xlabel('date')
plt.ylabel('price')
plt.show()
